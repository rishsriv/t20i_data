# %%
# %matplotlib inline

import json
import pandas as pd
import numpy as np

# %%
all_matches = pd.read_csv('all_t20i_05-16.csv')
all_matches = all_matches.sort('date', ascending = False)
matches = all_matches.match_id.values
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app

# %%
def f(i):
    return i['bat'], i['bowl'], i['o_u'], i['ovr'], i['r'], i['r_t'], i['x'], i['y'], i['z']

# %%
import os.path
failed_ids = []

for idx, match_id in enumerate(matches):
    if not os.path.exists('cleaned_data/%s_summary.csv'%match_id):
        try:
            wicket_data = json.load(open('data/%s-pie-wickets.json'%(match_id)))
            df = pd.io.json.read_json('data/%s-wagon-inning-1.json'%(match_id), dtype=False)    
            df['inning'] = 1
            df['batting_team'] = wicket_data['t1']['n']
            df['bowling_team'] = wicket_data['t2']['n']

            df2 = pd.io.json.read_json('data/%s-wagon-inning-2.json'%(match_id), dtype=False)
            df2['inning'] = 2
            df2['batting_team'] = wicket_data['t2']['n']
            df2['bowling_team'] = wicket_data['t1']['n']

            df['batsman'], df['bowler'], df['ball_num'], df['ovr'], df['runs_batter'], df['runs_w_extras'], df['x'], df['y'], df['z'] = zip(*df.runs.apply(f))
            df2['batsman'], df2['bowler'], df2['ball_num'], df2['ovr'], df2['runs_batter'], df2['runs_w_extras'], df2['x'], df2['y'], df2['z'] = zip(*df2.runs.apply(f))

            for param in ['ball_num', 'ovr', 'runs_batter', 'runs_w_extras', 'x', 'y', 'z']:
                df[param] = df[param].astype(float)
                df2[param] = df2[param].astype(float)

            from collections import defaultdict
            dismissals = defaultdict(dict)

            for i in wicket_data['t1']['w']:
                dismissals[float(i['ovr'])] = {'inning': 1, 'how': i['how'], 'ovr': float(i['ovr']), 'batsman': i['out'], 'bowler': i['outby']}

            for i in wicket_data['t2']['w']:
                dismissals[float(i['ovr'])] = {'inning': 2, 'how': i['how'], 'ovr': float(i['ovr']), 'batsman': i['out'], 'bowler': i['outby']}

            def add_wickets(inning, ovr, batsman, extras, unique, dismissals = dismissals):
                #Note: a run-out on a no-ball or wide will be double-counted
                if ovr in dismissals and dismissals[ovr]['inning'] == inning:
                    if unique == 'True':
                        return True, dismissals[ovr]['how'], dismissals[ovr]['batsman']
                    else:
                        if dismissals[ovr]['how'] != 'run out':
                            if extras == 0:
                                return True, dismissals[ovr]['how'], dismissals[ovr]['batsman']
                            else:
                                return False, np.nan, np.nan
                        else:
                            return True, dismissals[ovr]['how'], dismissals[ovr]['batsman'] #think of a better way later
                return False, np.nan, np.nan

            val_count_1 = df.ovr.value_counts()
            val_count_2 = df2.ovr.value_counts()

            def get_unique_1(i):
                if val_count_1[i] == 1:
                    return True
                return False

            def get_unique_2(i):
                if val_count_2[i] == 1:
                    return True
                return False

            df['ovr_unique'] = df.ovr.apply(get_unique_1)
            df2['ovr_unique'] = df2.ovr.apply(get_unique_2)
            df['extras'] = df['runs_w_extras'] - df['runs_batter']
            df2['extras'] = df2['runs_w_extras'] - df2['runs_batter']
            df['wicket'], df['wicket_method'], df['who_out'] = zip(*df.apply(lambda row: add_wickets(row['inning'], row['ovr'], row['batsman'], row['extras'], row['ovr_unique']), axis=1))
            df2['wicket'], df2['wicket_method'], df2['who_out'] = zip(*df2.apply(lambda row: add_wickets(row['inning'], row['ovr'], row['batsman'], row['extras'], row['ovr_unique']), axis=1))
            df['match_id'] = match_id
            df2['match_id'] = match_id

            df['cumul_runs'] = df['runs_w_extras'].cumsum()
            df['cumul_wickets'] = df['wicket'].cumsum()
            df['cumul_balls'] = df['ovr'].apply(lambda x: 6*int(x) + int(10*x)%10)
            df2['cumul_runs'] = df2['runs_w_extras'].cumsum()
            df2['cumul_wickets'] = df2['wicket'].cumsum()
            df2['cumul_balls'] = df2['ovr'].apply(lambda x: 6*int(x) + int(10*x)%10)

            player_db = {}
            inn_1_batting_order = {}
            inn_2_batting_order = {}
            for idx__, d in enumerate(wicket_data['t1']['p']):
                player_db.update(d)
                inn_1_batting_order[d.keys()[0]] = idx__+1
            for idx__, d in enumerate(wicket_data['t2']['p']):
                player_db.update(d)
                inn_2_batting_order[d.keys()[0]] = idx__+1

            def get_name(i):
                return player_db.get(i, None)

            df['batsman_name'] = df['batsman'].apply(get_name)
            df['bowler_name'] = df['bowler'].apply(get_name)
            df['who_out'] = df['who_out'].apply(get_name)
            df['batting_order'] = df['batsman'].apply(inn_1_batting_order.get)

            df2['batsman_name'] = df2['batsman'].apply(get_name)
            df2['bowler_name'] = df2['bowler'].apply(get_name)
            df2['who_out'] = df2['who_out'].apply(get_name)
            df2['batting_order'] = df2['batsman'].apply(inn_2_batting_order.get)

            df = df.append(df2)    
            df = df.drop('runs', axis=1)
            df = df.reset_index(drop=True)

            if os.path.isfile('data/%s_ball_details.txt'%(match_id)):
                try:
                    with open('data/%s_ball_details.txt'%(match_id), 'r') as fil:
                        a = eval(fil.read()[8:-2])
                    l = []
                    for i in a[0]['data']:
                        temp = i.values()[0].split(',')
                        l.append({'ball_speed': temp[3], 'landing_y': temp[4], 'landing_x': temp[5], 'bat_right_handed': temp[6],
                             'ended_x': temp[7], 'ended_y': temp[8]})
                    df2 = pd.DataFrame(l)
                    if len(df2) == len(df):
                        df = df.join(df2)
                        cols = ['inning', 'batting_team', 'bowling_team', 'batsman', 'bowler', 'batsman_name', 'batting_order',
                            'bowler_name', 'bat_right_handed', 'ovr', 'runs_batter', 'runs_w_extras', 'extras',
                            'x', 'y', 'z', 'landing_x', 'landing_y', 'ended_x', 'ended_y', 'ball_speed', 'cumul_runs',
                            'cumul_wickets', 'cumul_balls', 'wicket', 'wicket_method', 'who_out']
                    else:
                        print 'discrepancy', match_id
                        cols = ['inning', 'batting_team', 'bowling_team', 'batsman', 'bowler', 'batsman_name', 'batting_order',
                        'bowler_name', 'ovr', 'runs_batter', 'runs_w_extras', 'extras',
                        'x', 'y', 'z', 'cumul_runs', 'cumul_wickets', 'cumul_balls', 'wicket', 'wicket_method', 'who_out']
                except:
                    cols = ['inning', 'batting_team', 'bowling_team', 'batsman', 'bowler', 'batsman_name', 'batting_order',
                        'bowler_name', 'ovr', 'runs_batter', 'runs_w_extras', 'extras',
                        'x', 'y', 'z', 'cumul_runs', 'cumul_wickets', 'cumul_balls', 'wicket', 'wicket_method', 'who_out']
            df = df[cols]
            df.to_csv('cleaned_data/%s_summary.csv'%(match_id))
            print 'success', idx, len(matches)
        except:
            print 'failed', idx, match_id, len(matches)
            failed_ids.append(int(match_id))
    else:
        print 'already exists', idx, len(matches)
# Out:
# success 0 551
# success 1 551
# success 2 551
# already exists 3 551
# already exists 4 551
# already exists 5 551
# already exists 6 551
# already exists 7 551
# already exists 8 551
# already exists 9 551
# already exists 10 551
# already exists 11 551
# already exists 12 551
# already exists 13 551
# already exists 14 551
# already exists 15 551
# already exists 16 551
# already exists 17 551
# already exists 18 551
# already exists 19 551
# already exists 20 551
# already exists 21 551
# already exists 22 551
# already exists 23 551
# already exists 24 551
# already exists 25 551
# already exists 26 551
# already exists 27 551
# already exists 28 551
# already exists 29 551
# already exists 30 551
# already exists 31 551
# already exists 32 551
# already exists 33 551
# already exists 34 551
# already exists 35 551
# already exists 36 551
# already exists 37 551
# already exists 38 551
# already exists 39 551
# already exists 40 551
# already exists 41 551
# already exists 42 551
# already exists 43 551
# already exists 44 551
# already exists 45 551
# already exists 46 551
# already exists 47 551
# already exists 48 551
# already exists 49 551
# already exists 50 551
# already exists 51 551
# already exists 52 551
# already exists 53 551
# already exists 54 551
# already exists 55 551
# already exists 56 551
# already exists 57 551
# already exists 58 551
# already exists 59 551
# already exists 60 551
# already exists 61 551
# already exists 62 551
# already exists 63 551
# already exists 64 551
# already exists 65 551
# already exists 66 551
# already exists 67 551
# already exists 68 551
# already exists 69 551
# already exists 70 551
# already exists 71 551
# already exists 72 551
# already exists 73 551
# already exists 74 551
# already exists 75 551
# already exists 76 551
# already exists 77 551
# already exists 78 551
# already exists 79 551
# already exists 80 551
# already exists 81 551
# already exists 82 551
# already exists 83 551
# already exists 84 551
# already exists 85 551
# already exists 86 551
# already exists 87 551
# already exists 88 551
# already exists 89 551
# already exists 90 551
# already exists 91 551
# already exists 92 551
# already exists 93 551
# already exists 94 551
# already exists 95 551
# already exists 96 551
# already exists 97 551
# already exists 98 551
# already exists 99 551
# already exists 100 551
# already exists 101 551
# already exists 102 551
# already exists 103 551
# already exists 104 551
# already exists 105 551
# already exists 106 551
# already exists 107 551
# already exists 108 551
# already exists 109 551
# already exists 110 551
# already exists 111 551
# already exists 112 551
# already exists 113 551
# already exists 114 551
# already exists 115 551
# already exists 116 551
# already exists 117 551
# already exists 118 551
# already exists 119 551
# already exists 120 551
# already exists 121 551
# already exists 122 551
# already exists 123 551
# already exists 124 551
# already exists 125 551
# already exists 126 551
# already exists 127 551
# already exists 128 551
# already exists 129 551
# already exists 130 551
# already exists 131 551
# already exists 132 551
# already exists 133 551
# already exists 134 551
# already exists 135 551
# already exists 136 551
# already exists 137 551
# already exists 138 551
# already exists 139 551
# already exists 140 551
# already exists 141 551
# already exists 142 551
# already exists 143 551
# already exists 144 551
# already exists 145 551
# already exists 146 551
# already exists 147 551
# already exists 148 551
# already exists 149 551
# already exists 150 551
# already exists 151 551
# already exists 152 551
# already exists 153 551
# already exists 154 551
# already exists 155 551
# already exists 156 551
# already exists 157 551
# already exists 158 551
# already exists 159 551
# already exists 160 551
# already exists 161 551
# already exists 162 551
# already exists 163 551
# already exists 164 551
# already exists 165 551
# already exists 166 551
# already exists 167 551
# already exists 168 551
# already exists 169 551
# already exists 170 551
# already exists 171 551
# already exists 172 551
# already exists 173 551
# already exists 174 551
# already exists 175 551
# already exists 176 551
# already exists 177 551
# already exists 178 551
# already exists 179 551
# already exists 180 551
# already exists 181 551
# already exists 182 551
# already exists 183 551
# already exists 184 551
# already exists 185 551
# already exists 186 551
# already exists 187 551
# already exists 188 551
# already exists 189 551
# already exists 190 551
# already exists 191 551
# already exists 192 551
# already exists 193 551
# already exists 194 551
# already exists 195 551
# already exists 196 551
# already exists 197 551
# already exists 198 551
# already exists 199 551
# already exists 200 551
# already exists 201 551
# already exists 202 551
# already exists 203 551
# already exists 204 551
# already exists 205 551
# already exists 206 551
# already exists 207 551
# already exists 208 551
# already exists 209 551
# already exists 210 551
# already exists 211 551
# already exists 212 551
# already exists 213 551
# already exists 214 551
# already exists 215 551
# already exists 216 551
# already exists 217 551
# already exists 218 551
# already exists 219 551
# already exists 220 551
# already exists 221 551
# already exists 222 551
# already exists 223 551
# failed 224 660107 551
# already exists 225 551
# already exists 226 551
# already exists 227 551
# already exists 228 551
# already exists 229 551
# already exists 230 551
# already exists 231 551
# already exists 232 551
# already exists 233 551
# already exists 234 551
# already exists 235 551
# already exists 236 551
# already exists 237 551
# already exists 238 551
# already exists 239 551
# already exists 240 551
# already exists 241 551
# already exists 242 551
# already exists 243 551
# already exists 244 551
# already exists 245 551
# already exists 246 551
# already exists 247 551
# already exists 248 551
# already exists 249 551
# already exists 250 551
# already exists 251 551
# already exists 252 551
# already exists 253 551
# already exists 254 551
# already exists 255 551
# already exists 256 551
# already exists 257 551
# already exists 258 551
# already exists 259 551
# already exists 260 551
# already exists 261 551
# already exists 262 551
# already exists 263 551
# already exists 264 551
# already exists 265 551
# already exists 266 551
# already exists 267 551
# already exists 268 551
# already exists 269 551
# already exists 270 551
# already exists 271 551
# already exists 272 551
# already exists 273 551
# already exists 274 551
# already exists 275 551
# already exists 276 551
# already exists 277 551
# already exists 278 551
# already exists 279 551
# already exists 280 551
# already exists 281 551
# already exists 282 551
# already exists 283 551
# already exists 284 551
# already exists 285 551
# already exists 286 551
# already exists 287 551
# already exists 288 551
# already exists 289 551
# already exists 290 551
# already exists 291 551
# already exists 292 551
# already exists 293 551
# already exists 294 551
# already exists 295 551
# already exists 296 551
# already exists 297 551
# already exists 298 551
# already exists 299 551
# already exists 300 551
# already exists 301 551
# already exists 302 551
# already exists 303 551
# already exists 304 551
# already exists 305 551
# already exists 306 551
# already exists 307 551
# already exists 308 551
# already exists 309 551
# already exists 310 551
# already exists 311 551
# already exists 312 551
# already exists 313 551
# already exists 314 551
# already exists 315 551
# already exists 316 551
# already exists 317 551
# already exists 318 551
# already exists 319 551
# already exists 320 551
# already exists 321 551
# already exists 322 551
# already exists 323 551
# already exists 324 551
# already exists 325 551
# already exists 326 551
# already exists 327 551
# already exists 328 551
# already exists 329 551
# already exists 330 551
# already exists 331 551
# already exists 332 551
# already exists 333 551
# already exists 334 551
# already exists 335 551
# already exists 336 551
# already exists 337 551
# already exists 338 551
# already exists 339 551
# already exists 340 551
# already exists 341 551
# already exists 342 551
# already exists 343 551
# already exists 344 551
# already exists 345 551
# already exists 346 551
# already exists 347 551
# already exists 348 551
# already exists 349 551
# already exists 350 551
# already exists 351 551
# already exists 352 551
# already exists 353 551
# already exists 354 551
# already exists 355 551
# already exists 356 551
# already exists 357 551
# already exists 358 551
# already exists 359 551
# already exists 360 551
# already exists 361 551
# already exists 362 551
# already exists 363 551
# already exists 364 551
# already exists 365 551
# already exists 366 551
# already exists 367 551
# already exists 368 551
# already exists 369 551
# already exists 370 551
# already exists 371 551
# already exists 372 551
# already exists 373 551
# already exists 374 551
# already exists 375 551
# already exists 376 551
# already exists 377 551
# already exists 378 551
# already exists 379 551
# already exists 380 551
# already exists 381 551
# already exists 382 551
# already exists 383 551
# already exists 384 551
# already exists 385 551
# already exists 386 551
# already exists 387 551
# already exists 388 551
# already exists 389 551
# already exists 390 551
# already exists 391 551
# already exists 392 551
# already exists 393 551
# already exists 394 551
# already exists 395 551
# already exists 396 551
# already exists 397 551
# already exists 398 551
# already exists 399 551
# already exists 400 551
# already exists 401 551
# already exists 402 551
# already exists 403 551
# already exists 404 551
# already exists 405 551
# already exists 406 551
# already exists 407 551
# already exists 408 551
# already exists 409 551
# already exists 410 551
# already exists 411 551
# already exists 412 551
# already exists 413 551
# already exists 414 551
# already exists 415 551
# already exists 416 551
# already exists 417 551
# already exists 418 551
# already exists 419 551
# already exists 420 551
# already exists 421 551
# already exists 422 551
# already exists 423 551
# already exists 424 551
# already exists 425 551
# already exists 426 551
# already exists 427 551
# already exists 428 551
# already exists 429 551
# already exists 430 551
# already exists 431 551
# already exists 432 551
# already exists 433 551
# already exists 434 551
# already exists 435 551
# already exists 436 551
# already exists 437 551
# already exists 438 551
# already exists 439 551
# already exists 440 551
# already exists 441 551
# already exists 442 551
# already exists 443 551
# already exists 444 551
# already exists 445 551
# already exists 446 551
# already exists 447 551
# already exists 448 551
# already exists 449 551
# already exists 450 551
# already exists 451 551
# already exists 452 551
# already exists 453 551
# already exists 454 551
# already exists 455 551
# already exists 456 551
# already exists 457 551
# already exists 458 551
# already exists 459 551
# already exists 460 551
# already exists 461 551
# already exists 462 551
# already exists 463 551
# already exists 464 551
# already exists 465 551
# already exists 466 551
# already exists 467 551
# already exists 468 551
# already exists 469 551
# already exists 470 551
# already exists 471 551
# already exists 472 551
# already exists 473 551
# already exists 474 551
# already exists 475 551
# already exists 476 551
# already exists 477 551
# already exists 478 551
# already exists 479 551
# already exists 480 551
# already exists 481 551
# already exists 482 551
# already exists 483 551
# already exists 484 551
# already exists 485 551
# already exists 486 551
# already exists 487 551
# already exists 488 551
# already exists 489 551
# already exists 490 551
# already exists 491 551
# already exists 492 551
# already exists 493 551
# already exists 494 551
# already exists 495 551
# already exists 496 551
# already exists 497 551
# already exists 498 551
# already exists 499 551
# already exists 500 551
# already exists 501 551
# already exists 502 551
# already exists 503 551
# already exists 504 551
# already exists 505 551
# already exists 506 551
# already exists 507 551
# already exists 508 551
# already exists 509 551
# already exists 510 551
# already exists 511 551
# already exists 512 551
# already exists 513 551
# already exists 514 551
# already exists 515 551
# already exists 516 551
# already exists 517 551
# already exists 518 551
# already exists 519 551
# already exists 520 551
# already exists 521 551
# already exists 522 551
# already exists 523 551
# already exists 524 551
# already exists 525 551
# already exists 526 551
# already exists 527 551
# already exists 528 551
# already exists 529 551
# already exists 530 551
# already exists 531 551
# already exists 532 551
# already exists 533 551
# already exists 534 551
# already exists 535 551
# already exists 536 551
# already exists 537 551
# already exists 538 551
# already exists 539 551
# already exists 540 551
# already exists 541 551
# failed 542 264065 551
# already exists 543 551
# already exists 544 551
# already exists 545 551
# already exists 546 551
# already exists 547 551
# already exists 548 551
# already exists 549 551
# already exists 550 551

# %% [markdown]
# ### List of matches that were not parsed

# %%
all_matches[all_matches.match_id.isin(failed_ids)]
# Out:
#      Unnamed: 0   team1_name   team2_name  team1_id  team2_id ground_name  \
# 326         326  Afghanistan  Netherlands        40        15     Sharjah
# 8             8   Bangladesh     Zimbabwe        25         9      Khulna
#
#      ground_id  match_id        date
# 326      59392    660107  2013-11-15
# 8        56691    264065  2006-11-28
