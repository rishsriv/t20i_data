# %%
# %matplotlib inline

import json
import pandas as pd
import numpy as np

# %%
all_matches = pd.read_csv('all_t20i_05-16.csv')
all_matches = all_matches.sort('date', ascending = False)
matches = all_matches.match_id.values
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app

# %%
def f(i):
    return i['bat'], i['bowl'], i['o_u'], i['ovr'], i['r'], i['r_t'], i['x'], i['y'], i['z']

# %%
import os.path
failed_ids = []

for idx, match_id in enumerate(matches):
    if not os.path.exists('cleaned_data/%s_summary.csv'%match_id):
        try:
            wicket_data = json.load(open('data/%s-pie-wickets.json'%(match_id)))
            df = pd.io.json.read_json('data/%s-wagon-inning-1.json'%(match_id), dtype=False)    
            df['inning'] = 1
            df['batting_team'] = wicket_data['t1']['n']
            df['bowling_team'] = wicket_data['t2']['n']

            df2 = pd.io.json.read_json('data/%s-wagon-inning-2.json'%(match_id), dtype=False)
            df2['inning'] = 2
            df2['batting_team'] = wicket_data['t2']['n']
            df2['bowling_team'] = wicket_data['t1']['n']

            df['batsman'], df['bowler'], df['ball_num'], df['ovr'], df['runs_batter'], df['runs_w_extras'], df['x'], df['y'], df['z'] = zip(*df.runs.apply(f))
            df2['batsman'], df2['bowler'], df2['ball_num'], df2['ovr'], df2['runs_batter'], df2['runs_w_extras'], df2['x'], df2['y'], df2['z'] = zip(*df2.runs.apply(f))

            for param in ['ball_num', 'ovr', 'runs_batter', 'runs_w_extras', 'x', 'y', 'z']:
                df[param] = df[param].astype(float)
                df2[param] = df2[param].astype(float)

            from collections import defaultdict
            dismissals = defaultdict(dict)

            for i in wicket_data['t1']['w']:
                dismissals[float(i['ovr'])] = {'inning': 1, 'how': i['how'], 'ovr': float(i['ovr']), 'batsman': i['out'], 'bowler': i['outby']}

            for i in wicket_data['t2']['w']:
                dismissals[float(i['ovr'])] = {'inning': 2, 'how': i['how'], 'ovr': float(i['ovr']), 'batsman': i['out'], 'bowler': i['outby']}

            def add_wickets(inning, ovr, batsman, extras, unique, dismissals = dismissals):
                #Note: a run-out on a no-ball or wide will be double-counted
                if ovr in dismissals and dismissals[ovr]['inning'] == inning:
                    if unique == 'True':
                        return True, dismissals[ovr]['how'], dismissals[ovr]['batsman']
                    else:
                        if dismissals[ovr]['how'] != 'run out':
                            if extras == 0:
                                return True, dismissals[ovr]['how'], dismissals[ovr]['batsman']
                            else:
                                return False, np.nan, np.nan
                        else:
                            return True, dismissals[ovr]['how'], dismissals[ovr]['batsman'] #think of a better way later
                return False, np.nan, np.nan

            val_count_1 = df.ovr.value_counts()
            val_count_2 = df2.ovr.value_counts()

            def get_unique_1(i):
                if val_count_1[i] == 1:
                    return True
                return False

            def get_unique_2(i):
                if val_count_2[i] == 1:
                    return True
                return False

            df['ovr_unique'] = df.ovr.apply(get_unique_1)
            df2['ovr_unique'] = df2.ovr.apply(get_unique_2)
            df['extras'] = df['runs_w_extras'] - df['runs_batter']
            df2['extras'] = df2['runs_w_extras'] - df2['runs_batter']
            df['wicket'], df['wicket_method'], df['who_out'] = zip(*df.apply(lambda row: add_wickets(row['inning'], row['ovr'], row['batsman'], row['extras'], row['ovr_unique']), axis=1))
            df2['wicket'], df2['wicket_method'], df2['who_out'] = zip(*df2.apply(lambda row: add_wickets(row['inning'], row['ovr'], row['batsman'], row['extras'], row['ovr_unique']), axis=1))
            df['match_id'] = match_id
            df2['match_id'] = match_id

            df['cumul_runs'] = df['runs_w_extras'].cumsum()
            df['cumul_wickets'] = df['wicket'].cumsum()
            df['cumul_balls'] = df['ovr'].apply(lambda x: 6*int(x) + int(10*x)%10)
            df2['cumul_runs'] = df2['runs_w_extras'].cumsum()
            df2['cumul_wickets'] = df2['wicket'].cumsum()
            df2['cumul_balls'] = df2['ovr'].apply(lambda x: 6*int(x) + int(10*x)%10)

            player_db = {}
            inn_1_batting_order = {}
            inn_2_batting_order = {}
            for idx__, d in enumerate(wicket_data['t1']['p']):
                player_db.update(d)
                inn_1_batting_order[d.keys()[0]] = idx__+1
            for idx__, d in enumerate(wicket_data['t2']['p']):
                player_db.update(d)
                inn_2_batting_order[d.keys()[0]] = idx__+1

            def get_name(i):
                return player_db.get(i, None)

            df['batsman_name'] = df['batsman'].apply(get_name)
            df['bowler_name'] = df['bowler'].apply(get_name)
            df['who_out'] = df['who_out'].apply(get_name)
            df['batting_order'] = df['batsman'].apply(inn_1_batting_order.get)

            df2['batsman_name'] = df2['batsman'].apply(get_name)
            df2['bowler_name'] = df2['bowler'].apply(get_name)
            df2['who_out'] = df2['who_out'].apply(get_name)
            df2['batting_order'] = df2['batsman'].apply(inn_2_batting_order.get)

            df = df.append(df2)    
            df = df.drop('runs', axis=1)
            df = df.reset_index(drop=True)

            try:
                with open('data/%s_ball_details.txt'%(match_id), 'r') as fil:
                    a = eval(fil.read()[8:-2])
                l = []
                for i in a[0]['data']:
                    temp = i.values()[0].split(',')
                    l.append({'ball_speed': temp[3], 'landing_y': temp[4], 'landing_x': temp[5], 'bat_right_handed': temp[6],
                         'ended_x': temp[7], 'ended_y': temp[8]})
                df2 = pd.DataFrame(l)
                if len(df2) == len(df):
                    df = df.join(df2)
                    cols = ['inning', 'batting_team', 'bowling_team', 'batsman', 'bowler', 'batsman_name', 'batting_order',
                        'bowler_name', 'bat_right_handed', 'ovr', 'runs_batter', 'runs_w_extras', 'extras',
                        'x', 'y', 'z', 'landing_x', 'landing_y', 'ended_x', 'ended_y', 'ball_speed', 'cumul_runs',
                        'cumul_wickets', 'cumul_balls', 'wicket', 'wicket_method', 'who_out']
                else:
                    print 'discrepancy', match_id
                    cols = ['inning', 'batting_team', 'bowling_team', 'batsman', 'bowler', 'batsman_name', 'batting_order',
                    'bowler_name', 'ovr', 'runs_batter', 'runs_w_extras', 'extras',
                    'x', 'y', 'z', 'cumul_runs', 'cumul_wickets', 'cumul_balls', 'wicket', 'wicket_method', 'who_out']
            except:
                cols = ['inning', 'batting_team', 'bowling_team', 'batsman', 'bowler', 'batsman_name', 'batting_order',
                    'bowler_name', 'ovr', 'runs_batter', 'runs_w_extras', 'extras',
                    'x', 'y', 'z', 'cumul_runs', 'cumul_wickets', 'cumul_balls', 'wicket', 'wicket_method', 'who_out']
            df = df[cols]
            df.to_csv('cleaned_data/%s_summary.csv'%(match_id))
            print 'success', idx, len(matches)
        except:
            print 'failed', idx, match_id, len(matches)
            failed_ids.append(int(match_id))
    else:
        print 'already exists', idx, len(matches)
# Out:
# success 0 561
# success 1 561
# already exists 2 561
# already exists 3 561
# already exists 4 561
# already exists 5 561
# already exists 6 561
# already exists 7 561
# already exists 8 561
# already exists 9 561
# already exists 10 561
# already exists 11 561
# already exists 12 561
# already exists 13 561
# already exists 14 561
# already exists 15 561
# already exists 16 561
# already exists 17 561
# already exists 18 561
# already exists 19 561
# already exists 20 561
# already exists 21 561
# already exists 22 561
# already exists 23 561
# already exists 24 561
# already exists 25 561
# already exists 26 561
# already exists 27 561
# already exists 28 561
# already exists 29 561
# already exists 30 561
# already exists 31 561
# already exists 32 561
# already exists 33 561
# already exists 34 561
# already exists 35 561
# already exists 36 561
# already exists 37 561
# already exists 38 561
# already exists 39 561
# already exists 40 561
# already exists 41 561
# already exists 42 561
# already exists 43 561
# already exists 44 561
# already exists 45 561
# already exists 46 561
# already exists 47 561
# already exists 48 561
# already exists 49 561
# already exists 50 561
# already exists 51 561
# already exists 52 561
# already exists 53 561
# already exists 54 561
# already exists 55 561
# already exists 56 561
# already exists 57 561
# already exists 58 561
# already exists 59 561
# already exists 60 561
# already exists 61 561
# already exists 62 561
# already exists 63 561
# already exists 64 561
# already exists 65 561
# already exists 66 561
# already exists 67 561
# already exists 68 561
# already exists 69 561
# already exists 70 561
# already exists 71 561
# already exists 72 561
# already exists 73 561
# already exists 74 561
# already exists 75 561
# already exists 76 561
# already exists 77 561
# already exists 78 561
# already exists 79 561
# already exists 80 561
# already exists 81 561
# already exists 82 561
# already exists 83 561
# already exists 84 561
# already exists 85 561
# already exists 86 561
# already exists 87 561
# already exists 88 561
# already exists 89 561
# already exists 90 561
# already exists 91 561
# already exists 92 561
# already exists 93 561
# already exists 94 561
# already exists 95 561
# already exists 96 561
# already exists 97 561
# already exists 98 561
# already exists 99 561
# already exists 100 561
# already exists 101 561
# already exists 102 561
# already exists 103 561
# already exists 104 561
# already exists 105 561
# already exists 106 561
# already exists 107 561
# already exists 108 561
# already exists 109 561
# already exists 110 561
# already exists 111 561
# already exists 112 561
# already exists 113 561
# already exists 114 561
# already exists 115 561
# already exists 116 561
# already exists 117 561
# already exists 118 561
# already exists 119 561
# already exists 120 561
# already exists 121 561
# already exists 122 561
# already exists 123 561
# already exists 124 561
# already exists 125 561
# already exists 126 561
# already exists 127 561
# already exists 128 561
# already exists 129 561
# already exists 130 561
# already exists 131 561
# already exists 132 561
# already exists 133 561
# already exists 134 561
# already exists 135 561
# already exists 136 561
# already exists 137 561
# already exists 138 561
# already exists 139 561
# already exists 140 561
# already exists 141 561
# already exists 142 561
# already exists 143 561
# already exists 144 561
# already exists 145 561
# already exists 146 561
# already exists 147 561
# already exists 148 561
# already exists 149 561
# already exists 150 561
# already exists 151 561
# already exists 152 561
# already exists 153 561
# already exists 154 561
# already exists 155 561
# already exists 156 561
# already exists 157 561
# already exists 158 561
# already exists 159 561
# already exists 160 561
# already exists 161 561
# already exists 162 561
# already exists 163 561
# already exists 164 561
# already exists 165 561
# already exists 166 561
# already exists 167 561
# already exists 168 561
# already exists 169 561
# already exists 170 561
# already exists 171 561
# already exists 172 561
# already exists 173 561
# already exists 174 561
# already exists 175 561
# already exists 176 561
# already exists 177 561
# already exists 178 561
# already exists 179 561
# already exists 180 561
# already exists 181 561
# already exists 182 561
# already exists 183 561
# already exists 184 561
# already exists 185 561
# already exists 186 561
# already exists 187 561
# already exists 188 561
# already exists 189 561
# already exists 190 561
# already exists 191 561
# already exists 192 561
# already exists 193 561
# already exists 194 561
# already exists 195 561
# already exists 196 561
# already exists 197 561
# already exists 198 561
# already exists 199 561
# already exists 200 561
# already exists 201 561
# already exists 202 561
# already exists 203 561
# already exists 204 561
# already exists 205 561
# already exists 206 561
# already exists 207 561
# already exists 208 561
# already exists 209 561
# already exists 210 561
# already exists 211 561
# already exists 212 561
# already exists 213 561
# already exists 214 561
# already exists 215 561
# already exists 216 561
# already exists 217 561
# already exists 218 561
# already exists 219 561
# already exists 220 561
# already exists 221 561
# already exists 222 561
# already exists 223 561
# already exists 224 561
# already exists 225 561
# already exists 226 561
# already exists 227 561
# already exists 228 561
# already exists 229 561
# already exists 230 561
# already exists 231 561
# already exists 232 561
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-9bfa64d9681c> in <module>()
#      16         df2['bowling_team'] = wicket_data['t1']['n']
#      17
# ---> 18         df['batsman'], df['bowler'], df['ball_num'], df['ovr'], df['runs_batter'], df['runs_w_extras'], df['x'], df['y'], df['z'] = zip(*df.runs.apply(f))
#      19         df2['batsman'], df2['bowler'], df2['ball_num'], df2['ovr'], df2['runs_batter'], df2['runs_w_extras'], df2['x'], df2['y'], df2['z'] = zip(*df2.runs.apply(f))
#      20
#
# ValueError: need more than 0 values to unpack

# %% [markdown]
# ### List of matches that were not parsed

# %%
all_matches[all_matches.match_id.isin(failed_ids)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, team1_name, team2_name, team1_id, team2_id, ground_name, ground_id, match_id, date]
# Index: []
